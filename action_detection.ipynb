# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from PIL import Image
import os
from tqdm.notebook import tqdm

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
# Load the training and testing datasets
train_df = pd.read_csv('Training_set.csv')
test_df = pd.read_csv('Testing_set.csv')

# Inspect the first few rows of the training set
print("Training Set:")
print(train_df.head())

# Inspect the first few rows of the testing set
print("\nTesting Set:")
print(test_df.head())

# Check for null values
print("\nNull values in Training Set:", train_df.isnull().sum())
print("Null values in Testing Set:", test_df.isnull().sum())
# Out:
# Training Set:
#       filename         label
# 0  Image_1.jpg       sitting
# 1  Image_2.jpg  using_laptop
# 2  Image_3.jpg       hugging
# 3  Image_4.jpg      sleeping
# 4  Image_5.jpg  using_laptop
#
# Testing Set:
#       filename
# 0  Image_1.jpg
# 1  Image_2.jpg
# 2  Image_3.jpg
# 3  Image_4.jpg
# 4  Image_5.jpg
#
# Null values in Training Set: filename    0
# label       0
# dtype: int64
# Null values in Testing Set: filename    0
# dtype: int64

# %%
def display_random_images(dataframe, folder='train', n=4):
    plt.figure(figsize=(15, 15))
    for i in range(n):
        rnd = np.random.randint(0, len(dataframe))
        img_file = os.path.join(folder, dataframe['filename'].iloc[rnd])

        if os.path.exists(img_file):
            plt.subplot(1, n, i + 1)
            image = Image.open(img_file)
            plt.imshow(image)
            plt.title(dataframe['label'].iloc[rnd])
    plt.show()

# Display random images from the training set
display_random_images(train_df, folder='train')

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
y = lb.fit_transform(train_df['label'])
classes = lb.classes_
print("Classes:", classes)
# Out:
# Classes: ['calling' 'clapping' 'cycling' 'dancing' 'drinking' 'eating' 'fighting'
#  'hugging' 'laughing' 'listening_to_music' 'running' 'sitting' 'sleeping'
#  'texting' 'using_laptop']

# %%
x = train_df['filename'].values

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.1, random_state=100)

# %%
def preprocess_images(filenames, folder='train', img_size=(128, 128)):
    img_data = []
    for file in tqdm(filenames, desc="Processing Images"):
        img_path = os.path.join(folder, file)
        if os.path.exists(img_path):
            img = Image.open(img_path).convert('RGB')
            img = img.resize(img_size)
            img_data.append(np.array(img))
        else:
            print(f"Image {img_path} not found!")
    return np.array(img_data)

# Prepare image data
x_train_data = preprocess_images(x_train, folder='train')
x_val_data = preprocess_images(x_val, folder='train')

# Normalize pixel values
x_train_data = x_train_data / 255.0
x_val_data = x_val_data / 255.0

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(classes), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Display the model architecture
model.summary()

# Train the model
history = model.fit(
    x_train_data, y_train,
    validation_data=(x_val_data, y_val),
    epochs=50,
    batch_size=32,
    verbose=1
)
# Out:
# Processing Images:   0%|          | 0/89 [00:00<?, ?it/s]
# Processing Images:   0%|          | 0/10 [00:00<?, ?it/s]
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_10 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  dropout_15 (Dropout)        (None, 63, 63, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_11 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 30, 30, 64)        0
#
#  flatten_5 (Flatten)         (None, 57600)             0
#
#  dense_10 (Dense)            (None, 128)               7372928
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 15)                1935
#
# =================================================================
# Total params: 7,394,255
# Trainable params: 7,394,255
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3/3 [==============================] - 5s 1s/step - loss: 6.2826 - accuracy: 0.0674 - val_loss: 4.0433 - val_accuracy: 0.1000
# Epoch 2/50
# 3/3 [==============================] - 2s 795ms/step - loss: 5.2545 - accuracy: 0.0337 - val_loss: 2.9144 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 3/3 [==============================] - 2s 749ms/step - loss: 2.7574 - accuracy: 0.0562 - val_loss: 2.7320 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 3/3 [==============================] - 2s 728ms/step - loss: 2.6779 - accuracy: 0.1348 - val_loss: 2.7159 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 3/3 [==============================] - 2s 750ms/step - loss: 2.6764 - accuracy: 0.1236 - val_loss: 2.7120 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 3/3 [==============================] - 2s 750ms/step - loss: 2.6555 - accuracy: 0.1348 - val_loss: 2.7124 - val_accuracy: 0.1000
# Epoch 7/50
# 3/3 [==============================] - 2s 753ms/step - loss: 2.6486 - accuracy: 0.2247 - val_loss: 2.7161 - val_accuracy: 0.1000
# Epoch 8/50
# 3/3 [==============================] - 2s 724ms/step - loss: 2.6378 - accuracy: 0.1685 - val_loss: 2.7350 - val_accuracy: 0.1000
# Epoch 9/50
# 3/3 [==============================] - 2s 766ms/step - loss: 2.5992 - accuracy: 0.1573 - val_loss: 2.7787 - val_accuracy: 0.1000
# Epoch 10/50
# 3/3 [==============================] - 2s 766ms/step - loss: 2.5356 - accuracy: 0.1461 - val_loss: 2.7433 - val_accuracy: 0.1000
# Epoch 11/50
# 3/3 [==============================] - 2s 755ms/step - loss: 2.5137 - accuracy: 0.1798 - val_loss: 2.7402 - val_accuracy: 0.1000
# Epoch 12/50
# 3/3 [==============================] - 2s 749ms/step - loss: 2.4824 - accuracy: 0.2135 - val_loss: 2.7360 - val_accuracy: 0.1000
# Epoch 13/50
# 3/3 [==============================] - 2s 733ms/step - loss: 2.4013 - accuracy: 0.2360 - val_loss: 2.7489 - val_accuracy: 0.1000
# Epoch 14/50
# 3/3 [==============================] - 2s 772ms/step - loss: 2.3992 - accuracy: 0.2135 - val_loss: 2.7940 - val_accuracy: 0.1000
# Epoch 15/50
# 3/3 [==============================] - 2s 756ms/step - loss: 2.2513 - accuracy: 0.3034 - val_loss: 2.8040 - val_accuracy: 0.1000
# Epoch 16/50
# 3/3 [==============================] - 2s 761ms/step - loss: 2.1111 - accuracy: 0.3371 - val_loss: 2.8225 - val_accuracy: 0.1000
# Epoch 17/50
# 3/3 [==============================] - 2s 728ms/step - loss: 2.1094 - accuracy: 0.3483 - val_loss: 2.8517 - val_accuracy: 0.1000
# Epoch 18/50
# 3/3 [==============================] - 2s 765ms/step - loss: 2.0541 - accuracy: 0.3708 - val_loss: 2.7459 - val_accuracy: 0.1000
# Epoch 19/50
# 3/3 [==============================] - 2s 747ms/step - loss: 1.8576 - accuracy: 0.4831 - val_loss: 2.7355 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 3/3 [==============================] - 2s 724ms/step - loss: 1.7637 - accuracy: 0.3820 - val_loss: 2.8279 - val_accuracy: 0.1000
# Epoch 21/50
# 3/3 [==============================] - 2s 749ms/step - loss: 1.6486 - accuracy: 0.5730 - val_loss: 2.8560 - val_accuracy: 0.1000
# Epoch 22/50
# 3/3 [==============================] - 2s 748ms/step - loss: 1.4230 - accuracy: 0.5506 - val_loss: 2.8755 - val_accuracy: 0.2000
# Epoch 23/50
# 3/3 [==============================] - 2s 758ms/step - loss: 1.2428 - accuracy: 0.5618 - val_loss: 2.9820 - val_accuracy: 0.1000
# Epoch 24/50
# 3/3 [==============================] - 2s 736ms/step - loss: 1.2776 - accuracy: 0.6180 - val_loss: 2.9107 - val_accuracy: 0.1000
# Epoch 25/50
# 3/3 [==============================] - 2s 724ms/step - loss: 1.2151 - accuracy: 0.6404 - val_loss: 2.9609 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 3/3 [==============================] - 2s 734ms/step - loss: 1.0659 - accuracy: 0.6517 - val_loss: 2.9625 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 3/3 [==============================] - 2s 774ms/step - loss: 0.8808 - accuracy: 0.6742 - val_loss: 3.2751 - val_accuracy: 0.1000
# Epoch 28/50
# 3/3 [==============================] - 2s 768ms/step - loss: 0.9139 - accuracy: 0.7528 - val_loss: 3.2351 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 3/3 [==============================] - 2s 739ms/step - loss: 0.7498 - accuracy: 0.7303 - val_loss: 3.2003 - val_accuracy: 0.1000
# Epoch 30/50
# 3/3 [==============================] - 2s 799ms/step - loss: 0.6067 - accuracy: 0.8202 - val_loss: 3.2699 - val_accuracy: 0.2000
# Epoch 31/50
# 3/3 [==============================] - 2s 757ms/step - loss: 0.6009 - accuracy: 0.8090 - val_loss: 3.5275 - val_accuracy: 0.2000
# Epoch 32/50
# 3/3 [==============================] - 2s 773ms/step - loss: 0.5748 - accuracy: 0.8090 - val_loss: 3.8058 - val_accuracy: 0.1000
# Epoch 33/50
# 3/3 [==============================] - 2s 778ms/step - loss: 0.4335 - accuracy: 0.8652 - val_loss: 3.5896 - val_accuracy: 0.1000
# Epoch 34/50
# 3/3 [==============================] - 2s 731ms/step - loss: 0.5544 - accuracy: 0.8202 - val_loss: 3.2511 - val_accuracy: 0.1000
# Epoch 35/50
# 3/3 [==============================] - 2s 758ms/step - loss: 0.6977 - accuracy: 0.7416 - val_loss: 3.3450 - val_accuracy: 0.1000
# Epoch 36/50
# 3/3 [==============================] - 2s 743ms/step - loss: 0.4356 - accuracy: 0.8539 - val_loss: 3.8229 - val_accuracy: 0.2000
# Epoch 37/50
# 3/3 [==============================] - 2s 749ms/step - loss: 0.4906 - accuracy: 0.8427 - val_loss: 4.2327 - val_accuracy: 0.1000
# Epoch 38/50
# 3/3 [==============================] - 2s 751ms/step - loss: 0.3847 - accuracy: 0.8764 - val_loss: 3.6865 - val_accuracy: 0.1000
# Epoch 39/50
# 3/3 [==============================] - 2s 753ms/step - loss: 0.4825 - accuracy: 0.8315 - val_loss: 3.4962 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 3/3 [==============================] - 2s 712ms/step - loss: 0.5756 - accuracy: 0.7865 - val_loss: 3.4025 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 3/3 [==============================] - 2s 741ms/step - loss: 0.3414 - accuracy: 0.8764 - val_loss: 3.6275 - val_accuracy: 0.1000
# Epoch 42/50
# 3/3 [==============================] - 2s 764ms/step - loss: 0.4255 - accuracy: 0.8427 - val_loss: 3.9037 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 3/3 [==============================] - 2s 766ms/step - loss: 0.3804 - accuracy: 0.8427 - val_loss: 4.2536 - val_accuracy: 0.1000
# Epoch 44/50
# 3/3 [==============================] - 2s 744ms/step - loss: 0.4377 - accuracy: 0.8315 - val_loss: 4.2460 - val_accuracy: 0.1000
# Epoch 45/50
# 3/3 [==============================] - 2s 726ms/step - loss: 0.4075 - accuracy: 0.8539 - val_loss: 3.9778 - val_accuracy: 0.2000
# Epoch 46/50
# 3/3 [==============================] - 2s 766ms/step - loss: 0.3365 - accuracy: 0.8652 - val_loss: 3.7798 - val_accuracy: 0.1000
# Epoch 47/50
# 3/3 [==============================] - 2s 748ms/step - loss: 0.3405 - accuracy: 0.9101 - val_loss: 4.1399 - val_accuracy: 0.1000
# Epoch 48/50
# 3/3 [==============================] - 2s 744ms/step - loss: 0.4273 - accuracy: 0.8090 - val_loss: 4.3178 - val_accuracy: 0.2000
# Epoch 49/50
# 3/3 [==============================] - 2s 743ms/step - loss: 0.3452 - accuracy: 0.8764 - val_loss: 4.0819 - val_accuracy: 0.1000
# Epoch 50/50
# 3/3 [==============================] - 2s 726ms/step - loss: 0.2839 - accuracy: 0.8989 - val_loss: 3.9369 - val_accuracy: 0.1000

# %%
print()

# %%
model.save('action_recognition_model.h5')
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Test prediction function with image display
def test_predict(image_path):
    try:
        if not os.path.exists(image_path):
            print(f"Image not found: {image_path}")
            return

        # Load and preprocess image
        img = Image.open(image_path).convert('RGB')
        img = img.resize((128, 128))
        img_array = np.array(img) / 255.0
        img_array = np.expand_dims(img_array, axis=0)

        # Predict
        predictions = model.predict(img_array)
        predicted_class = classes[np.argmax(predictions)]
        probability = np.max(predictions) * 100

        # Display image and result
        plt.figure(figsize=(6, 6))
        original_img = Image.open(image_path)
        plt.imshow(original_img)
        plt.title(f"Predicted: {predicted_class}\nProbability: {probability:.2f}%")
        plt.axis('off')
        plt.show()

        # Print result in terminal
        print(f"\n{image_path}")
        print(f"1/1 [==============================] - 0s")
        print(f"probability: {probability:.2f}%")
        print(f"Predicted class : {predicted_class}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
test_predict('C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_37.jpg')
# Out:
# 1/1 [==============================] - 0s 77ms/step
# C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_37.jpg
# 1/1 [==============================] - 0s
# probability: 56.73%
# Predicted class : cycling

# %%
test_predict('C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_60.jpg')
# Out:
# 1/1 [==============================] - 0s 67ms/step
# C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_60.jpg
# 1/1 [==============================] - 0s
# probability: 52.77%
# Predicted class : calling

# %%
test_predict('C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_94.jpg')
# Out:
# 1/1 [==============================] - 0s 60ms/step
# C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_94.jpg
# 1/1 [==============================] - 0s
# probability: 29.47%
# Predicted class : sleeping

# %%
test_predict('C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_51.jpg')
# Out:
# 1/1 [==============================] - 0s 52ms/step
# C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_51.jpg
# 1/1 [==============================] - 0s
# probability: 23.57%
# Predicted class : using_laptop

# %%
test_predict('C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_36.jpg')
# Out:
# 1/1 [==============================] - 0s 77ms/step
# C:/Users/Dell/Downloads/00_Action_Detection-master/Action_Detection-master/project/Human Action Recognition/test/Image_36.jpg
# 1/1 [==============================] - 0s
# probability: 28.92%
# Predicted class : sleeping
